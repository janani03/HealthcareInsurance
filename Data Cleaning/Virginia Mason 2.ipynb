# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
#Setting low_memory = 'False' because my columns have multiple data types
df = pd.read_csv ("Virginia Mason - Understanding Data.csv", low_memory = False, header = None)

df.head()
# Out:
#                                                  0                1    \
# 0                                      hospital_name  last_updated_on
# 1                      Virginia Mason Medical Center         1/1/2025
# 2                                        description           code|1
# 3  CEREBRAL PERF ANALYSIS W/CTR ADM, INCL POST PR...            0042T
# 4  US ABLATION OF UTERINE LEIOMYOMATA, LESS THAN ...            0071T
#
#            2                              3    \
# 0      version              hospital_location
# 1        2.0.0  Virginia Mason Medical Center
# 2  code|1|type                         code|2
# 3          CDM                          0042T
# 4          CDM                          0071T
#
#                                 4                    5    \
# 0                  hospital_address  license_number | WA
# 1  1100 9th Ave., Seattle, WA 98101      HAC.FS.00000010
# 2                       code|2|type               code|3
# ...

# %%
new_header = df.iloc[2]  # The second row becomes the header
df = df[2:]              # Skip the first two rows (0: metadata, 1: headers)
df.columns = new_header      # Assign new header
df.reset_index(drop=True, inplace=True)

df
# Out:
# 2                                             description  code|1  \
# 0                                             description  code|1
# 1       CEREBRAL PERF ANALYSIS W/CTR ADM, INCL POST PR...   0042T
# 2       US ABLATION OF UTERINE LEIOMYOMATA, LESS THAN ...   0071T
# 3       US ABLATION OF UTERINE LEIOMYOMATA, GRTR THAN ...   0072T
# 4       TRSCTH PLCMNT EXTRACRANIAL VERTEBRAL/INTRATHOR...   0075T
# ...                                                   ...     ...
# 130236                       Hearing aid binaural glasses   V5230
# 130237                       Disp fee contralateral binau   V5240
# 130238                       Disp fee contralateral binau   V5240
# 130239                       Disp fee contralateral binau   V5240
# 130240                              Dispensing fee bicros   V5240
#
# 2       code|1|type  code|2  code|2|type  code|3  code|3|type  code|4  \
# 0       code|1|type  code|2  code|2|type  code|3  code|3|type  code|4
# ...

# %%
df = df.iloc[1:].reset_index(drop=True)
df
# Out:
# 2                                             description code|1 code|1|type  \
# 0       CEREBRAL PERF ANALYSIS W/CTR ADM, INCL POST PR...  0042T         CDM
# 1       US ABLATION OF UTERINE LEIOMYOMATA, LESS THAN ...  0071T         CDM
# 2       US ABLATION OF UTERINE LEIOMYOMATA, GRTR THAN ...  0072T         CDM
# 3       TRSCTH PLCMNT EXTRACRANIAL VERTEBRAL/INTRATHOR...  0075T         CDM
# 4       TRNSCTH PLC XTRACRNL VRTBRL/INTRTHRC CA STNT E...  0076T         CDM
# ...                                                   ...    ...         ...
# 130235                       Hearing aid binaural glasses  V5230       HCPCS
# 130236                       Disp fee contralateral binau  V5240       HCPCS
# 130237                       Disp fee contralateral binau  V5240       HCPCS
# 130238                       Disp fee contralateral binau  V5240       HCPCS
# 130239                              Dispensing fee bicros  V5240       HCPCS
#
# ...

# %%
df.describe()
# Out:
# 2                        description  code|1 code|1|type code|2 code|2|type  \
# count                         130240  130233      130233  39527       39527
# unique                         83139   79052           6   8350           1
# top     Electrophysiology evaluation   92014         CDM  C1713         CPT
# freq                              83       9       62674  12023       39527
#
# 2      code|3 code|3|type         code|4 code|4|type billing_class  ...  \
# count   56763       56763           2450        2450        130240  ...
# unique    140           1           2169           1             2  ...
# top       278          RC  00006-4045-00         NDC      facility  ...
# freq    35926       56763              4        2450         74427  ...
#
# 2      standard_charge|United Healthcare|Commercial|negotiated_algorithm  \
# count                                                   0
# unique                                                  0
# ...

# %%
# Out:
# /var/folders/nc/jvf2g8f13ks5xcnf_vn2lrjm0000gn/T/ipykernel_16781/1303816331.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df_data[df["code|2|type"] == "CPT"].reset_index(drop=True)
# 1                                            description code|1 code|1|type  \
# 0      CEREBRAL PERF ANALYSIS W/CTR ADM, INCL POST PR...  0042T         CDM
# 1      US ABLATION OF UTERINE LEIOMYOMATA, LESS THAN ...  0071T         CDM
# 2      US ABLATION OF UTERINE LEIOMYOMATA, GRTR THAN ...  0072T         CDM
# 3      TRSCTH PLCMNT EXTRACRANIAL VERTEBRAL/INTRATHOR...  0075T         CDM
# 4      TRNSCTH PLC XTRACRNL VRTBRL/INTRTHRC CA STNT E...  0076T         CDM
# ...                                                  ...    ...         ...
# 23569  POWASSAN VIRUS IGM ENZYME LINKED IMMUNOSORBENT...   8673         CDM
# 23570              CTNNB1 MUTATION ANALYSIS NEO GENOMICS   8593         CDM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130240 entries, 0 to 130239
# Columns: 157 entries, description to additional_payer_notes|United Healthcare|Medicare Advantage
# dtypes: object(157)
# memory usage: 156.0+ MB

# %%
subset_columns = [
    'description',
    'code|2',
    'code|2|type',
    'standard_charge|United Healthcare|Commercial|negotiated_algorithm',
    'estimated_amount|United Healthcare|Commercial',
    'standard_charge|United Healthcare|Commercial|methodology',
    'additional_payer_notes|United Healthcare|Commercial',
    'standard_charge|United Healthcare|Medicare Advantage|negotiated_dollar',
    'standard_charge|United Healthcare|Medicare Advantage|negotiated_percentage',
    'standard_charge|United Healthcare|Medicare Advantage|negotiated_algorithm',
    'estimated_amount|United Healthcare|Medicare Advantage',
    'standard_charge|United Healthcare|Medicare Advantage|methodology',
    'additional_payer_notes|United Healthcare|Medicare Advantage'
]

# Create the subset DataFrame
subset_df = df[subset_columns]

# %%
subset_df
# Out:
# 2                                             description code|2 code|2|type  \
# 0       CEREBRAL PERF ANALYSIS W/CTR ADM, INCL POST PR...  0042T         CPT
# 1       US ABLATION OF UTERINE LEIOMYOMATA, LESS THAN ...  0071T         CPT
# 2       US ABLATION OF UTERINE LEIOMYOMATA, GRTR THAN ...  0072T         CPT
# 3       TRSCTH PLCMNT EXTRACRANIAL VERTEBRAL/INTRATHOR...  0075T         CPT
# 4       TRNSCTH PLC XTRACRNL VRTBRL/INTRTHRC CA STNT E...  0076T         CPT
# ...                                                   ...    ...         ...
# 130235                       Hearing aid binaural glasses    NaN         NaN
# 130236                       Disp fee contralateral binau    NaN         NaN
# 130237                       Disp fee contralateral binau    NaN         NaN
# 130238                       Disp fee contralateral binau    NaN         NaN
# 130239                              Dispensing fee bicros    NaN         NaN
#
# ...

# %%
subset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130240 entries, 0 to 130239
# Data columns (total 13 columns):
#  #   Column                                                                      Non-Null Count   Dtype
# ---  ------                                                                      --------------   -----
#  0   description                                                                 130240 non-null  object
#  1   code|2                                                                      39527 non-null   object
#  2   code|2|type                                                                 39527 non-null   object
#  3   standard_charge|United Healthcare|Commercial|negotiated_algorithm           0 non-null       object
#  4   estimated_amount|United Healthcare|Commercial                               67 non-null      object
#  5   standard_charge|United Healthcare|Commercial|methodology                    29433 non-null   object
# ...

# %%
df_2 = subset_df[subset_df["code|2|type"] == "CPT"].reset_index(drop=True)
df_2
# Out:
# 2                                            description code|2 code|2|type  \
# 0      CEREBRAL PERF ANALYSIS W/CTR ADM, INCL POST PR...  0042T         CPT
# 1      US ABLATION OF UTERINE LEIOMYOMATA, LESS THAN ...  0071T         CPT
# 2      US ABLATION OF UTERINE LEIOMYOMATA, GRTR THAN ...  0072T         CPT
# 3      TRSCTH PLCMNT EXTRACRANIAL VERTEBRAL/INTRATHOR...  0075T         CPT
# 4      TRNSCTH PLC XTRACRNL VRTBRL/INTRTHRC CA STNT E...  0076T         CPT
# ...                                                  ...    ...         ...
# 39522                  SEPT9 METHYLATION ANALYSIS - TECH  81327         CPT
# 39523                    MOPATH PROCEDURE LEVEL 5 - TECH  81404         CPT
# 39524                 ONC CHEMO RX CYTOTOX CSC 14 - TECH  0564T         CPT
# 39525  INFECT AGENT DETECT BY DNA OR RNA, RESP VIRUS,...  87631         CPT
# 39526                              GROSS HEMOLYSIS BLOOD  85999         CPT
#
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39527 entries, 0 to 39526
# Data columns (total 13 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   description                                                                 39527 non-null  object
#  1   code|2                                                                      39527 non-null  object
#  2   code|2|type                                                                 39527 non-null  object
#  3   standard_charge|United Healthcare|Commercial|negotiated_algorithm           0 non-null      object
#  4   estimated_amount|United Healthcare|Commercial                               0 non-null      object
#  5   standard_charge|United Healthcare|Commercial|methodology                    0 non-null      object
# ...
